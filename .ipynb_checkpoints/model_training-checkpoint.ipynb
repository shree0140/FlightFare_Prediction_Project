# %% [markdown]
# # Importing LIbraries

# %%
# !pip install feature-engine
# !pip install matplotlib
# !pip install xgboost


import numpy as np
import pandas as pd
import sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from feature_engine.datetime import DatetimeFeatures

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import learning_curve
from xgboost import XGBRegressor

import joblib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: feature-engine in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from feature-engine) (2.1.1)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from feature-engine) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from feature-engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from feature-engine) (1.14.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from feature-engine) (0.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from pandas>=2.2.0->feature-engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from pandas>=2.2.0->feature-engine) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (24.1)
# Requirement already satisfied: six in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from xgboost) (2.1.1)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\envs\project_env\lib\site-packages (from xgboost) (1.14.1)

# %%
#import sys
#print(sys.executable)

# %% [markdown]
# # 2.Display Settings

# %%
pd.set_option("display.max_columns", None)

# %%
sklearn.set_config(transform_output="default")

# %% [markdown]
# # 3.Getting Data

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-03-21     Delhi      Cochin  06:50:00
# 1            Air India      2019-06-24  Banglore       Delhi  21:05:00
# 2    Multiple Carriers      2019-05-21     Delhi      Cochin  09:00:00
# 3    Multiple Carriers      2019-03-27     Delhi      Cochin  10:45:00
# 4               Indigo      2019-06-06  Banglore       Delhi  08:30:00
# ..                 ...             ...       ...         ...       ...
# 635        Jet Airways      2019-03-27     Delhi      Cochin  19:10:00
# 636        Jet Airways      2019-05-15   Kolkata    Banglore  18:55:00
# 637          Air India      2019-05-24   Kolkata    Banglore  09:25:00
# 638  Multiple Carriers      2019-06-03     Delhi      Cochin  09:15:00
# 639           Air Asia      2019-05-06   Kolkata    Banglore  07:35:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       07:40:00      1490          2.0                      No Info  11071
# 1       23:55:00       170          0.0                      No Info   6961
# 2       19:15:00       615          1.0                      No Info  14848
# 3       19:15:00       510          1.0                      No Info   7154
# 4       11:20:00       170          0.0                      No Info   4823
# ..           ...       ...          ...                          ...    ...
# 635     19:45:00      1475          2.0  In-flight meal not included   8834
# 636     19:50:00      1495          1.0  In-flight meal not included  10844
# 637     05:25:00      1200          2.0                      No Info  14897
# 638     19:00:00       585          1.0                      No Info  11622
# 639     23:30:00       955          1.0                      No Info   5192
#
# [640 rows x 10 columns]

# %%
val_df = pd.read_csv("val.csv")

# %%
val_df
# Out:
#          airline date_of_journey   source destination  dep_time arrival_time  \
# 0    Jet Airways      2019-05-01  Kolkata    Banglore  20:25:00     10:55:00
# 1    Jet Airways      2019-06-15    Delhi      Cochin  02:15:00     04:25:00
# 2         Indigo      2019-05-27    Delhi      Cochin  17:10:00     01:30:00
# 3         Indigo      2019-04-12  Kolkata    Banglore  20:20:00     22:55:00
# 4       Spicejet      2019-06-21  Kolkata    Banglore  17:10:00     19:40:00
# ..           ...             ...      ...         ...       ...          ...
# 155    Air India      2019-06-03    Delhi      Cochin  10:00:00     19:15:00
# 156       Indigo      2019-05-15    Delhi      Cochin  02:00:00     07:45:00
# 157       Indigo      2019-05-06  Kolkata    Banglore  15:15:00     20:05:00
# 158  Jet Airways      2019-05-21    Delhi      Cochin  11:30:00     12:35:00
# 159  Jet Airways      2019-06-12  Kolkata    Banglore  16:30:00     12:00:00
#
#      duration  total_stops              additional_info  price
# 0         870          1.0                      No Info  12121
# 1        1570          1.0  In-flight meal not included  10262
# 2         500          1.0                      No Info   6206
# 3         155          0.0                      No Info   4488
# 4         150          0.0                      No Info   3873
# ..        ...          ...                          ...    ...
# 155       555          1.0                      No Info  10979
# 156       345          1.0                      No Info   6037
# 157       290          1.0                      No Info   4775
# 158      1505          1.0  In-flight meal not included  12898
# 159      1170          1.0  In-flight meal not included   8529
#
# [160 rows x 10 columns]

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df
# Out:
#          airline date_of_journey    source destination  dep_time arrival_time  \
# 0      Air India      2019-05-18     Delhi      Cochin  05:10:00     08:00:00
# 1       Spicejet      2019-03-27   Kolkata    Banglore  09:00:00     11:30:00
# 2    Jet Airways      2019-03-27     Delhi      Cochin  11:30:00     04:25:00
# 3    Jet Airways      2019-03-09     Delhi      Cochin  02:15:00     04:25:00
# 4    Jet Airways      2019-05-09     Delhi      Cochin  19:45:00     19:00:00
# ..           ...             ...       ...         ...       ...          ...
# 195     Spicejet      2019-03-27     Delhi      Cochin  15:55:00     21:55:00
# 196  Jet Airways      2019-06-03     Delhi      Cochin  19:15:00     19:00:00
# 197     Spicejet      2019-06-09  Banglore       Delhi  21:10:00     00:05:00
# 198    Air India      2019-05-06  Banglore       Delhi  06:10:00     08:55:00
# 199    Air India      2019-03-01  Banglore   New Delhi  22:00:00     13:20:00
#
#      duration  total_stops               additional_info  price
# 0         170          0.0                       No Info   6934
# 1         150          0.0  No check-in baggage included   3815
# 2        1015          1.0                       No Info  12242
# 3        1570          1.0   In-flight meal not included  11848
# 4        1395          1.0   In-flight meal not included  12373
# ..        ...          ...                           ...    ...
# 195       360          1.0                       No Info   5111
# 196      1425          1.0                       No Info  14714
# 197       175          0.0                       No Info   3971
# 198       165          0.0                       No Info   6121
# 199       920          1.0                       No Info  21130
#
# [200 rows x 10 columns]

# %% [markdown]
# # 3.1 Splitting the data

# %%
def split_data(data):
	X = data.drop(columns="price")
	y = data.price.copy()
	return (X, y)

# %%
X_train, y_train = split_data(train_df)

# %%
X_train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-03-21     Delhi      Cochin  06:50:00
# 1            Air India      2019-06-24  Banglore       Delhi  21:05:00
# 2    Multiple Carriers      2019-05-21     Delhi      Cochin  09:00:00
# 3    Multiple Carriers      2019-03-27     Delhi      Cochin  10:45:00
# 4               Indigo      2019-06-06  Banglore       Delhi  08:30:00
# ..                 ...             ...       ...         ...       ...
# 635        Jet Airways      2019-03-27     Delhi      Cochin  19:10:00
# 636        Jet Airways      2019-05-15   Kolkata    Banglore  18:55:00
# 637          Air India      2019-05-24   Kolkata    Banglore  09:25:00
# 638  Multiple Carriers      2019-06-03     Delhi      Cochin  09:15:00
# 639           Air Asia      2019-05-06   Kolkata    Banglore  07:35:00
#
#     arrival_time  duration  total_stops              additional_info
# 0       07:40:00      1490          2.0                      No Info
# 1       23:55:00       170          0.0                      No Info
# 2       19:15:00       615          1.0                      No Info
# 3       19:15:00       510          1.0                      No Info
# 4       11:20:00       170          0.0                      No Info
# ..           ...       ...          ...                          ...
# 635     19:45:00      1475          2.0  In-flight meal not included
# 636     19:50:00      1495          1.0  In-flight meal not included
# 637     05:25:00      1200          2.0                      No Info
# 638     19:00:00       585          1.0                      No Info
# 639     23:30:00       955          1.0                      No Info
#
# [640 rows x 9 columns]

# %%
y_train
# Out:
# 0      11071
# 1       6961
# 2      14848
# 3       7154
# 4       4823
#        ...
# 635     8834
# 636    10844
# 637    14897
# 638    11622
# 639     5192
# Name: price, Length: 640, dtype: int64

# %%
X_val, y_val = split_data(val_df)

# %%
print(X_val.shape, y_val.shape)
# Out:
# (160, 9) (160,)

# %%
X_test, y_test = split_data(test_df)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (200, 9) (200,)

# %% [markdown]
# # 3.2 Meta Info

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          640 non-null    object
#  1   date_of_journey  640 non-null    object
#  2   source           640 non-null    object
#  3   destination      640 non-null    object
#  4   dep_time         640 non-null    object
#  5   arrival_time     640 non-null    object
#  6   duration         640 non-null    int64
#  7   total_stops      640 non-null    float64
#  8   additional_info  640 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 45.1+ KB

# %% [markdown]
# # 4. Data Preprocessing

# %%
#Numerical Columns:

num_cols = ["duration", "total_stops"]

# %%
#Date-Time Columns:

dt_cols = ["date_of_journey", "dep_time", "arrival_time"]

# %%
#Categorical Columns:

cat_cols = [col for col in X_train.columns if (col not in dt_cols) and (col not in num_cols)]

# %%
cat_cols
# Out:
# ['airline', 'source', 'destination', 'additional_info']

# %%
num_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="median")),
	("scaler", StandardScaler())
])

# %%
cat_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("encoder", OneHotEncoder(sparse_output=False, handle_unknown="ignore"))
])

# %%
doj_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("extractor", DatetimeFeatures(features_to_extract=["month", "week", "day_of_week", "day_of_month"], format="mixed")),
	("scaler", StandardScaler())
])

# %%
time_transformer = Pipeline(steps=[
	("imputer", SimpleImputer(strategy="most_frequent")),
	("extractor", DatetimeFeatures(features_to_extract=["hour", "minute"], format="mixed")),
	("scaler", StandardScaler())
])

# %%
preprocessor = ColumnTransformer(transformers=[
	("num", num_transformer, num_cols),
	("cat", cat_transformer, cat_cols),
	("doj", doj_transformer, ["date_of_journey"]),
	("time", time_transformer, ["dep_time", "arrival_time"])
])

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[ 1.88417547,  1.95253061,  0.        , ...,  1.31402724,
#         -0.92028432,  0.88158885],
#        [-0.89241768, -1.17934806,  0.        , ..., -1.02058007,
#          1.38098832,  1.75906453],
#        [ 0.04363077,  0.38659127,  0.        , ..., -1.27998088,
#          0.80567016, -0.58087062],
#        ...,
#        [ 1.27416637,  1.95253061,  0.        , ...,  0.01702318,
#         -1.2079434 ,  0.00411317],
#        [-0.01947362,  0.38659127,  0.        , ..., -0.50177845,
#          0.80567016, -1.4583463 ],
#        [ 0.75881385,  0.38659127,  1.        , ...,  0.5358248 ,
#          1.38098832,  0.29660506]])

# %%
preprocessor.fit_transform(X_train).shape
# Out:
# (640, 33)

# %% [markdown]
# # 5.Model Selection

# %%
algorithms = {
	"Linear Regression": LinearRegression(),
	"Support Vector Machine": SVR(),
	"Random Forest": RandomForestRegressor(n_estimators=10),
	"XG Boost": XGBRegressor(n_estimators=10)
}

# %%
data = pd.concat([train_df, val_df], axis=0)
data
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-03-21     Delhi      Cochin  06:50:00
# 1            Air India      2019-06-24  Banglore       Delhi  21:05:00
# 2    Multiple Carriers      2019-05-21     Delhi      Cochin  09:00:00
# 3    Multiple Carriers      2019-03-27     Delhi      Cochin  10:45:00
# 4               Indigo      2019-06-06  Banglore       Delhi  08:30:00
# ..                 ...             ...       ...         ...       ...
# 155          Air India      2019-06-03     Delhi      Cochin  10:00:00
# 156             Indigo      2019-05-15     Delhi      Cochin  02:00:00
# 157             Indigo      2019-05-06   Kolkata    Banglore  15:15:00
# 158        Jet Airways      2019-05-21     Delhi      Cochin  11:30:00
# 159        Jet Airways      2019-06-12   Kolkata    Banglore  16:30:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       07:40:00      1490          2.0                      No Info  11071
# 1       23:55:00       170          0.0                      No Info   6961
# 2       19:15:00       615          1.0                      No Info  14848
# 3       19:15:00       510          1.0                      No Info   7154
# 4       11:20:00       170          0.0                      No Info   4823
# ..           ...       ...          ...                          ...    ...
# 155     19:15:00       555          1.0                      No Info  10979
# 156     07:45:00       345          1.0                      No Info   6037
# 157     20:05:00       290          1.0                      No Info   4775
# 158     12:35:00      1505          1.0  In-flight meal not included  12898
# 159     12:00:00      1170          1.0  In-flight meal not included   8529
#
# [800 rows x 10 columns]

# %%
X_data, y_data = split_data(data)
print(X_data.shape, y_data.shape)
# Out:
# (800, 9) (800,)

# %%
def plot_curves(sizes, mean_scores, std_scores, label, ax):
	ax.plot(
		sizes,
		mean_scores,
		marker="o",
		label=label
	)

	ax.fill_between(
		x=sizes,
		y1=mean_scores - std_scores,
		y2=mean_scores + std_scores,
		alpha=0.5
	)

# %%
def plot_learning_curves(name, algorithm, figsize=(12, 4)):
	model = Pipeline(steps=[
		("pre", preprocessor),
		("alg", algorithm)
	])

	train_sizes, train_scores, test_scores = learning_curve(
		estimator=model,
		X=X_data,
		y=y_data,
		cv=3,
		scoring="r2",
		n_jobs=-1,
		random_state=42
	)
	
	mean_train_scores = np.mean(train_scores, axis=1)
	std_train_scores = np.std(train_scores, axis=1)
	train_score = f"{mean_train_scores[-1]:.2f} +/- {std_train_scores[-1]:.2f}"

	mean_test_scores = np.mean(test_scores, axis=1)
	std_test_scores = np.std(test_scores, axis=1)
	test_score = f"{mean_test_scores[-1]:.2f} +/- {std_test_scores[-1]:.2f}"

	fig, ax = plt.subplots(figsize=figsize)

	# training curve
	plot_curves(
		train_sizes,
		mean_train_scores,
		std_train_scores,
		f"Train ({train_score})",
		ax
	)

	# test curve
	plot_curves(
		train_sizes,
		mean_test_scores,
		std_test_scores,
		f"Test ({test_score})",
		ax
	)

	ax.set(xlabel="Training Set Size", ylabel="R-square", title=name)

	ax.legend(loc="lower right")

	plt.show()

# %%
for name, alg in algorithms.items():
	plot_learning_curves(name, alg)
    
#following are the learning curves for different algos:

# %% [markdown]
# # 6. Model Training

# %%
model = Pipeline(steps=[
	("pre", preprocessor),
	("rf", RandomForestRegressor(n_estimators=10))
])

# %%
model.fit(X_data, y_data)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %% [markdown]
# # 7. Model Evaluation

# %%
def evaluate_model(X, y):
	y_pred = model.predict(X)
	return r2_score(y, y_pred)

# %%
print(f"R2 score on Training data is = {evaluate_model(X_data, y_data)}")
# Out:
# R2 score on Training data is = 0.9561054777874719

# %%
print(f"R2 score on Test data is = {evaluate_model(X_test, y_test)}")
# Out:
# R2 score on Test data is = 0.7575780360060174

# %% [markdown]
# # 8. Model Persistence

# %%
joblib.dump(model, "model.joblib")
# Out:
# ['model.joblib']

# %%
saved_model = joblib.load("model.joblib")
saved_model
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %%
y_pred = saved_model.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# 0.7575780360060174
